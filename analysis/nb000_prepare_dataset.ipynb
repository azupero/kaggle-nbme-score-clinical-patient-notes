# %%
# !pip install -q --upgrade --force-reinstall --no-deps kaggle
# Out:
#      |████████████████████████████████| 58 kB 3.9 MB/s
# ...

# %%
# !mkdir /root/.kaggle
# !cp /content/drive/MyDrive/Colab/kaggle/kaggle.json /root/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c nbme-score-clinical-patient-notes
# Out:
# ...
#  61% 6.00M/9.83M [00:00<00:00, 61.2MB/s]
# 100% 9.83M/9.83M [00:00<00:00, 90.7MB/s]

# %%
# !unzip nbme-score-clinical-patient-notes.zip -d /content/drive/MyDrive/Colab/kaggle/nbme-score-clinical-patient-notes/input
# Out:
# Archive:  nbme-score-clinical-patient-notes.zip
#   inflating: /content/drive/MyDrive/Colab/kaggle/nbme-score-clinical-patient-notes/input/features.csv
#   inflating: /content/drive/MyDrive/Colab/kaggle/nbme-score-clinical-patient-notes/input/patient_notes.csv
#   inflating: /content/drive/MyDrive/Colab/kaggle/nbme-score-clinical-patient-notes/input/sample_submission.csv
#   inflating: /content/drive/MyDrive/Colab/kaggle/nbme-score-clinical-patient-notes/input/test.csv
#   inflating: /content/drive/MyDrive/Colab/kaggle/nbme-score-clinical-patient-notes/input/train.csv
